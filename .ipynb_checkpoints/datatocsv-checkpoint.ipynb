# %%
import pandas as pd
import pickle

# %%
data = pd.read_pickle('pickle\\data_sent.pkl')
data.index.name = 'movie'
data
# Out:
#                                                                      transcripts  \
# movie
# Howls Moving Castle             sophie ive closed up the shop you should come...
# Spirited Away                   good luck chihiro well meet again chihiro chi...
# Princess Mononoke              in ancient times the land lay covered in fores...
# From Up on Poppy Hill                                                        ...
# The Secret World of Arietty    studio ghibli nippon television network dentsu...
# Ponyo                           ponyo on the cliff seaweeds waving gently in ...
# Whisper of the Heart                                hey  hey      good evenin...
# Porco Rosso                    due to the threat of fascism and world war l a...
# Kiki's Delivery Service        but first heres the weather forecast skies are...
# My Neighbor Totoro                totoro     arukou arukou watashi wa genki l...
# ...

# %%
data.transcripts['From Up on Poppy Hill']
# Out:
# '                                                                 morning   good morning is sora up yet   still in front of the mirror   morning   good morning   night shift again   and tonight too   shall i save dinner for you   yes thanks   thats real service   the hospitals shorthanded    alti got a hole in my sock   leave it by the sewing machine   more holes     not my fault my socks keep shrinking   this is for you   sis pack me a jumbo lunch   dont you eat enough already   here riku have my fried egg   all right   you need it more dr hokuto   whos the doctor here   you drown everything in soy sauce   i like it that way   me too   breakfast is ready hiro   good morning hana   good morning   you can share your mothers   thanks   can i make you some tea   no thanks ive had some   good morning   morning   thanks   please go ahead everyone   lets eat    youre late   i cant get my hair right   you look very pretty   im starving   evening rounds again dr hokuto   yes   see you tomorr
# ...

# %%
header = ['producer', 'polarity', 'subjectivity']

# %%
data.to_csv(r'CSV\movie_sentiment.csv', columns = header)
