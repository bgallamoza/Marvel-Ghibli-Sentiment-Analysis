# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy

# %matplotlib inline

# %%
data = pd.read_pickle('pickle\\data_sent.pkl')
data.index.name = 'movie'
data
# Out:
#                                                                      transcripts  \
# movie
# Howls Moving Castle             sophie ive closed up the shop you should come...
# Spirited Away                   good luck chihiro well meet again chihiro chi...
# Princess Mononoke              in ancient times the land lay covered in fores...
# From Up on Poppy Hill                                                        ...
# The Secret World of Arietty    studio ghibli nippon television network dentsu...
# Ponyo                           ponyo on the cliff seaweeds waving gently in ...
# Whisper of the Heart                                hey  hey      good evenin...
# Porco Rosso                    due to the threat of fascism and world war l a...
# Kiki's Delivery Service        but first heres the weather forecast skies are...
# My Neighbor Totoro                totoro     arukou arukou watashi wa genki l...
# ...

# %%
data_melt = pd.melt(data, #dataframe
                   ['transcripts', 'producer'], #Variables to KEEP
                   var_name='test',
                   ignore_index=False) #Every other var is melted to this

data_melt
# Out:
#                                                                      transcripts  \
# movie
# Howls Moving Castle             sophie ive closed up the shop you should come...
# Spirited Away                   good luck chihiro well meet again chihiro chi...
# Princess Mononoke              in ancient times the land lay covered in fores...
# From Up on Poppy Hill                                                        ...
# The Secret World of Arietty    studio ghibli nippon television network dentsu...
# Ponyo                           ponyo on the cliff seaweeds waving gently in ...
# Whisper of the Heart                                hey  hey      good evenin...
# Porco Rosso                    due to the threat of fascism and world war l a...
# Kiki's Delivery Service        but first heres the weather forecast skies are...
# My Neighbor Totoro                totoro     arukou arukou watashi wa genki l...
# ...

# %%
sns.set_style(style='whitegrid')
g = sns.FacetGrid(data=data_melt,col='test',sharey=False,col_order=['polarity','subjectivity'])
g.map(sns.barplot, x='producer',
                y='value',
                data=data_melt,
     order=data_melt.producer.unique(),
     hue_order=data_melt.producer.unique,
     palette=sns.color_palette(['red','blue']),
     capsize=.3,
     errwidth=1.2,
     alpha=.7)
g.set_axis_labels('Producer','Value')
g.set_titles('average {col_name} of movies')

# %%
g.savefig('output.png')

# %%
polar_plot = sns.barplot(data=data,x='producer',y='polarity')
subj_plot = sns.barplot(data=data,x='producer',y='subjectivity')

fig, (ax1, ax2) = plt.subplots(1,2, sharex=True)
ax1.plot(polar_plot)
ax2.plot(subj_plot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d018fd082a7d> in <module>
#       3
#       4 fig, (ax1, ax2) = plt.subplots(1,2, sharex=True)
# ----> 5 ax1.plot(polar_plot)
#       6 ax2.plot(subj_plot)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# -> 1745             self.add_line(line)
#    1746         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1747         return lines
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1962             line.set_clip_path(self.patch)
#    1963
# -> 1964         self._update_line_limits(line)
#    1965         if not line.get_label():
# ...
